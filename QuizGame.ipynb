# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotidabass/Question_Quiz/blob/main/QuizGame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/cherryWood55/Quiz-Game
# Out:
# fatal: destination path 'Quiz-Game' already exists and is not an empty directory.

# %%
#!/usr/bin/env python3
import json
import time

TOPICS_LIST = ['science', 'history', 'commerce', 'technology', 'worldgk'] 
# this list has to in sync with the JSON filename and the Menu prompt inside test() method

def ask_one_question(question):
    print("\n" + question)
    choice = input("Enter Your Choice [a/b/c/d]: ")
    while(True):
        if choice.lower() in ['a', 'b', 'c', 'd']:
            return choice
        else:
            print("Invalid choice. Enter again")
            choice = input("Enter Choice [a/b/c/d]: ")

def score_one_result(key, meta):
    actual = meta["answer"]
    if meta["user_response"].lower() == actual.lower():
        print("Q.{0} Absolutely Correct!\n".format(key))
        return 2
    else:
        print("Q.{0} Incorrect!".format(key))
        print("Right Answer is ({0})".format(actual))
        print ("Learn more : " + meta["more_info"] + "\n")
        return -1


def test(questions):
    score = 0
    print("General Instructions:\n1. Please enter only the choice letter corresponding to the correct answer.\n2. Each question carries 2 points\n3. Wrong answer leads to -1 marks per question\nQuiz will start momentarily. Good Luck!\n")
    time.sleep(10)
    for key, meta in questions.items():
        questions[key]["user_response"] = ask_one_question(meta["question"])
    print("\n***************** RESULT ********************\n")
    for key, meta in questions.items():
        score += score_one_result(key, meta)
    print("Your Score:", score, "/", (2 * len(questions)))

def load_question(filename):
    """
    loads the questions from the JSON file into a Python dictionary and returns it
    """
    questions = None
    with open('/content/Quiz-Game/topics/history.json', "r") as read_file:
        questions = json.load(read_file)
    return (questions)


def play_quiz():
    flag = False
    try:
        choice = int(input("Welcome to Today's Quiz!\nChoose your domain of interest:\n(1). Science\n(2). History of India\n(3). Commerce\n(4). Technology\n(5). World Gk\nEnter Your Choice [1/2/3/4/5]: "))
        if choice > len(TOPICS_LIST) or choice < 1:
            print("Invalid Choice. Enter Again")
            flag = True # raising flag
    except ValueError as e:
        print("Invalid Choice. Enter Again")
        flag = True # raising a flag

    if not flag:
        questions = load_question('topics/'+TOPICS_LIST[choice-1]+'.json')
        test(questions)
    else:
        play_quiz() # replay if flag was raised

def user_begin_prompt():
    print("Wanna test your GK?\nA. Yes\nB. No")
    play = input()
    if play.lower() == 'a' or play.lower() ==  'y':
        play_quiz()
    elif play.lower() == 'b':
        print("Hope you come back soon!")
    else:
        print("Hmm. I didn't quite understand that.\nPress A to play, or B to quit.")
        user_begin_prompt()
        
def execute():
    user_begin_prompt()

if __name__ == '__main__':
    execute()
# Out:
# Wanna test your GK?
# A. Yes
# B. No
# A
# Welcome to Today's Quiz!
# Choose your domain of interest:
# (1). Science
# (2). History of India
# (3). Commerce
# (4). Technology
# (5). World Gk
# Enter Your Choice [1/2/3/4/5]: 1
# General Instructions:
# 1. Please enter only the choice letter corresponding to the correct answer.
# 2. Each question carries 2 points
# 3. Wrong answer leads to -1 marks per question
# Quiz will start momentarily. Good Luck!
#
#
# The Indian National Congress was founded by:
# (a) A.O.Hume
# (b) Bal Gangadhar Tilak
# (c) Motilal Nehru
# (d) Surendranath Banerjee
#
# Enter Your Choice [a/b/c/d]: a
#
# The author of 'Poverty and Un-British Rule in India is
# (a) R. C. Dutt
# (b) Dadabhai Naoroji
# (c) Lala Lajpat Rai
# (d) Surendra Nath Banerjee
#
# Enter Your Choice [a/b/c/d]: a
#
# Who among the following was popularly known as the Frontier Gandhi?
# (a) Hasrat Mohani
# (b) Maulana Abul Kalam Azad
# (c) Khan Abdul Ghaffar Khan
# (d) Iqbal Khan
#
# Enter Your Choice [a/b/c/d]: a
#
# When did the First World War begin?
# (a) 28th July 1914
# (b) 20th July 1913
# (c) 28th May 1900
# (d) 28th June 1914
#
# Enter Your Choice [a/b/c/d]: a
#
# In the eighteenth century, which king was regarded as 'the most dangerous rival' in Mysore by the British?
# (a) Banda Bahadur
# (b) Ahmed Shah Abdali
# (c) Shah Alam II
# (d) Hyder Ali
#
# Enter Your Choice [a/b/c/d]: a
#
# Who was the first president of India?
# (a) Rajendra Prasad
# (b) Ram Nath Kovind
# (c) Sarvepalli Radhakrishnan
# (d) Mohammad Hidayatullah
#
# Enter Your Choice [a/b/c/d]: a
#
# The Rowlatt Act was passed in:
# (a)1905
# (b)1913
# (c)1919
# (d)1925
#
# Enter Your Choice [a/b/c/d]: a
#
# The Gandhi-Irwin Pact was signed on:
# (a)July 8, 1931
# (b)March 8, 1931
# (c)January 8, 1931
# (d)June 8, 1931
#
# Enter Your Choice [a/b/c/d]: a
#
# Aurobindo Ghose, Barindra Kumar Ghose, B.P. Mitra, Abinash Bhattacharya and Bhupendranath Dutta were associated with the revolutionary organization:
# (a)Anushilan Samiti (in Bengal)
# (b)Satya Shodhak Samaj
# (c)Bengal Society
# (d)Lok Pal Party
#
# Enter Your Choice [a/b/c/d]: a
# Enter Your Choice [a/b/c/d]: a
#
# Who was Henry VIIIs last wife?:
# (a)Catherine of Aragon
# (b)Jane Seymour
# (c)Catherine Howard
# (d)Catherine Parr
#
#
# What colour were the pyramids at Giza originally?:
# (a)Red
# (b)White
# (c)Brown
# (d)Gray
#
# Enter Your Choice [a/b/c/d]: a
#
# What was the name of the mythological monster that had nine heads?:
# (a)Kraken
# (b)Scylla
# (c)Hydra
# (d)Sirens
#
# Enter Your Choice [a/b/c/d]: a
#
# Who were the Axis powers in World War- II:
# (a)Poland, Japan, Germany
# (b)Germany, Italy, Japan
# (c)Italy, Japan, Britain
# (d)Germany, Italy, France
#
# Enter Your Choice [a/b/c/d]: a
#
# The term “Cold War” was coined by:
# (a)Palmer Perkins
# (b)Prof. Lippmann
# (c)Bernard Baruch
# (d)Roosevelt
#
# Enter Your Choice [a/b/c/d]: a
#
# The East India Association was set up in:
# (a)1866
# (b)1857
# (c)1836
# (d)1885
#
# Enter Your Choice [a/b/c/d]: a
#
# In 1932, Poona Pact was signed between:
# (a)Gandhiji and Jawahar Lal Nehru
# (b)Gandhiji and Dr. B. R. Ambedkar
# (c)Dr. B. R. Ambedkar and Jawahar Lal Nehru
# (d)Gandhiji and Md. Ali Jinnah
#
# Enter Your Choice [a/b/c/d]: a
#
# Which movement was started Mahatma Gandhi on March 12, 1930:
# (a)Khilafat movement
# (b)Quit India Movement
# (c)Noncooperation Co-operation
# (d) Civil Disobedience Movement
#
# Enter Your Choice [a/b/c/d]: a
#
# The First Round Table was held on:
# (a)November 12, 1930
# (b)December 12, 1930
# (c)November 12, 1937
# (d) October 12, 1930
#
# Enter Your Choice [a/b/c/d]: a
#
# Which is considered as oldest civilization of the world ?:
# (a)Mesopotamian Civilization
# (b)Egyptain Civilization
# (c)Harappan Civilization
# (d)Chinese Civilization
#
# Enter Your Choice [a/b/c/d]: a
#
# Who is known as Man of Blood and Iron?:
# (a)Napoleon
# (b)Bismarck
# (c)Ho Chi Minh
# (d)Sir Walter Scott
#
# Enter Your Choice [a/b/c/d]: a
#
# Who among the following were the first to invade India?:
# (a)Afghan
# (b)Moguls
# (c)Arabs
# (d)Turks
#
# Enter Your Choice [a/b/c/d]: a
#
# The paintings in the Ajanta and Ellora caves are indicative of development of art under the...:
# (a)Rashtrakutas
# (b)Pallavas
# (c)Pandya’s
# (d)Chalukyas
#
# Enter Your Choice [a/b/c/d]: a
#
# The first Indian ruler, who established the supremacy of Indian Navy in the Arabian Sea was:
# (a)Rajaraja 1
# (b)Rajendra 1
# (c)Rajadhiraja 1
# (d)Kulottunga 1
#
# Enter Your Choice [a/b/c/d]: a
#
# The first newspaper published in India in 1780 was:
# (a)The Bengal Gazette or Calcutta General Advertiser
# (b)The Calcutta Chronicle
# (c)The Madras Courier
# (d)The Bombay Herald
#
# Enter Your Choice [a/b/c/d]: a
#
# Where did Gautama Buddha delivered his first sermon, known as Dharma Chakra Pravartan:
# (a)Sanchi
# (b)Sarnath
# (c)Sravasti
# (d)Bodh Gaya
#
# Enter Your Choice [a/b/c/d]: a
#
# Who translated Ramayana into Persian?:
# (a)Abdul Fazi
# (b)Badauni
# (c)Isar Das
# (d)Abdul Latif
#
# Enter Your Choice [a/b/c/d]: a
#
# Chinese traveller Hiuen-Tsang studied at the University of:
# (a)Taxila
# (b)Magadh
# (c)Vikramshila
# (d)Nalanda
#
# Enter Your Choice [a/b/c/d]: a
#
# The ancient name of North Bihar was:
# (a)Vajji
# (b)Vatsa
# (c)Surasena
# (d) Avant
#
# Enter Your Choice [a/b/c/d]: a
# Enter Your Choice [a/b/c/d]: a
#
# Who amongst the following was a contemporary of Gautama Buddha?:
# (a)Bhadrabahu
# (b)Chandragupta Maurya
# (c)Parsvanath
# (d)Vardhaman Mahavira
#
#
# Which one of the following dynasties was ruling over North India at the time of Alexander's invasion:
# (a)Nanda
# (b)Maurya
# (c)Sunga
# (d)Kanva
#
# Enter Your Choice [a/b/c/d]: a
# Enter Your Choice [a/b/c/d]: a
#
# Which one of the following scripts of ancient India was written from right to left?:
# (a)Brahmi
# (b)Kharoshti
# (c)Nandnagari
# (d)Sharada
#
#
# The Chinese traveller Hiuen Tsang, called the prince of pilgrims visited India during the reign of :
# (a)Harsha
# (b)Chandragupta II
# (c)Dharampala
# (d)Devapala
#
# Enter Your Choice [a/b/c/d]: a
# Enter Your Choice [a/b/c/d]: a
#
# Who was the first Indian ruler who had territory outside India ?:
# (a)Ashoka
# (b)Chandra Guptha Maurya
# (c)Huvishka
# (d)Kanishka
#
#
# Who was the last Mughal Emperor of India?:
# (a)Akbar II
# (b)Bahadur Shah II
# (c)Alamgir II
# (d)Shah Alam II
#
# Enter Your Choice [a/b/c/d]: a
# Enter Your Choice [a/b/c/d]: a
#
# The battle of Mahabharata is believed to have been foughts at Kurukshetra for:
# (a)14 days
# (b)16 days
# (c)18 days
# (d)20 days
#
#
# The `Peloponnesian war` was fought between:
# (a)Sparta and Macedon
# (b)Athens and Persia
# (c)Sparta and Athens
# (d)Sparta and Corinth
#
# Enter Your Choice [a/b/c/d]: a
# Enter Your Choice [a/b/c/d]: a
#
# Who was the first woman in space?:
# (a)Sunitha Williams
# (b)Valentina Tereshkova
# (c)Masida namisha
# (d)Tamara Press
#
#
# A king of the Roman Empire, in 37 B.C, became the most powerful and ruled for 44 years.Who was that king?:
# (a)Octavian
# (b)Julius Caeser
# (c)Lapidus
# (d)Mark Antony
#
# Enter Your Choice [a/b/c/d]: a
# Enter Your Choice [a/b/c/d]: a
#
# Who was the last Emperor of Rome?:
# (a)Nero
# (b)Caeser
# (c)Romulus Augustulus
# (d)Julius
#
#
# Who wrote the first history book?:
# (a)Herodotus
# (b)Euclid
# (c)Julius Caesar
# (d)Aristotle
#
# Enter Your Choice [a/b/c/d]: a
# Enter Your Choice [a/b/c/d]: a
#
# Who started the construction of the Colosseum in Rome?:
# (a)Nero
# (b)Titus
# (c)Octavian
# (d)Vespasian
#
#
# In which decade was the SPICE simulator introduced:
# (a)1962
# (b)1972
# (c)1982
# (d)1992
#
# Enter Your Choice [a/b/c/d]: a
#
# Kargil War against Pakistan started in the year?:
# (a)1961
# (b)1965
# (c)1972
# (d)1999
#
# Enter Your Choice [a/b/c/d]: a
#
# Gateway of India was built by:
# (a)Frank Lloyd Wright
# (b)George Wittet
# (c)Frank Gehry
# (d)Zaha Hadid
#
# Enter Your Choice [a/b/c/d]: a
# Enter Your Choice [a/b/c/d]: a
#
# Who was the First Governor General of Bengal?:
# (a)Lord William Bentinck
# (b)Sir William Denison
# (c)The Lord Napier
# (d)Warren Hastings
#
#
# Name the British General who was responsible for the Jallianwalla Bagh massacre.:
# (a)Dyer
# (b)Hastings
# (c)Cornwallis
# (d)Dalhousie
#
# Enter Your Choice [a/b/c/d]: a
#
# Who was the first Viceroy of India?:
# (a)Lord Canning
# (b)Lord Curzon
# (c)Lord Mountbatten
# (d)Lord Wavell
#
# Enter Your Choice [a/b/c/d]: a
#
# Where and when the first session of Indian National Congress was held?:
# (a)Delhi, 1890
# (b)Mumbai, 1885
# (c)Madras, 1887
# (d)Kolkata, 1889
#
# Enter Your Choice [a/b/c/d]: a
#
# ***************** RESULT ********************
#
# Q.1 Absolutely Correct!
#
# Q.2 Incorrect!
# Right Answer is (b)
# Learn more : In 1867, Dadabhai Naoroji put forward the 'drain of wealth' theory in which he stated that the Britain was completely draining India. He mentioned this theory in his book Poverty and Un-British Rule in India.
#
# Q.3 Incorrect!
# Right Answer is (c)
# Learn more : Khan Abdul Ghaffar Khan, leader of the Pukhtuns, was given the sobriquet of 'Sarhadi Gandhi' by his followers in reference to his commitment to the freedom struggle and non-violence. Ghaffar Khan was a great admirer of Mahatma Gandhi.
#
# Q.4 Absolutely Correct!
#
# Q.5 Incorrect!
# Right Answer is (d)
# Learn more : Hyder Ali was the Sultan and de facto ruler of the Kingdom of Mysore in southern India. Born as Sayyid wal Sharif Hyder Ali Khan, he distinguished himself militarily, eventually drawing the attention of Mysore's rulers.
#
# Q.35 Incorrect!
# Right Answer is (c)
# Learn more : The Kurukshetra War, also called the Mahabharata War, is a war described in the Hindu epic poem Mahābhārata. The conflict arose from a dynastic succession struggle between two groups of cousins, the Kauravas and Pandavas, for the throne of Hastinapura. It involved several ancient kingdoms participating as allies of the rival groups. The war lasted exactly for eighteen days, since sunrise to sunset.
#
# Q.36 Incorrect!
# Right Answer is (c)
# Learn more : The Peloponnesian war, between Athens and Sparta from 431 to 404 BC ended in the defeat of Athens and the destruction of her democracy. Athens became a subject state of sparta. This war marked the beginning of the end of the `Glory that was Greece`.
#
# Q.37 Incorrect!
# Right Answer is (b)
# Learn more : On June 16, 1963, aboard Vostok 6, Soviet Cosmonaut Valentina Tereshkova becomes the first woman to travel into space. After 48 orbits and 71 hours, she returned to earth, having spent more time in space than all U.S. astronauts combined to that date.
#
# Q.40 Absolutely Correct!
#
# Q.41 Incorrect!
# Right Answer is (c)
# Learn more : Flavius Romulus Augustus (c. AD 460 – after AD 476; possibly still alive as late as AD 507), known derisively and historiographically as Romulus Augustulus, was the Roman emperor who ruled the Western Roman Empire from 31 October 475 until 4 September 476. He is often described as the 'last Western Roman emperor'. His deposition by Odoacer traditionally marks the end of the Roman Empire in the West, the end of Ancient Rome, and the beginning of the Middle Ages in Western Europe.
#
# Q.42 Absolutely Correct!
#
# Q.43 Incorrect!
# Right Answer is (d)
# Learn more : The Colosseum, also named the Flavian Amphitheater, is a large amphitheater in Rome. It was built during the reign of the Flavian emperors as a gift to the Roman people. Construction of the Colosseum began sometime between A.D. 70 and 72 under the emperor Vespasian. It opened nearly a decade later and was modified several times in the following years. When the Colosseum first opened, the emperor Titus celebrated with a hundred days of gladiatorial games. Emperors traditionally attended the games. The emperor Commodus is known to have performed in the arena on hundreds of occasions. Aside from the games, the Colosseum also hosted dramas, reenactments, and even public executions.
#
# Q.44 Incorrect!
# Right Answer is (b)
# Learn more : SPICE (Simulation Program with Integrated Circuit Emphasis) was introduced in May 1972 by the University of Berkeley, California.
#
# Q.45 Incorrect!
# Right Answer is (d)
# Learn more : The Kargil War, also known as the Kargil conflict, was an armed conflict between India and Pakistan that took place between May and July 1999 in the Kargil district of Kashmir and elsewhere along the Line of Control (LOC).
#
# Q.46 Incorrect!
# Right Answer is (b)
# Learn more : In 1911 King George V and queen Mary visited Delhi so to commemorate the arrival of their king, the British decided to make a gateway of India. The chief architect of this gateway was George Wittet. Its construction was completed in 1911. The gateway was opened on 4th December 1924, by the Viceroy, the Earl of Reading. Its central dome is 15 metres in diameter, and touches the height of 26 metres above the ground.
#
# Q.47 Incorrect!
# Right Answer is (c)
# Learn more : The Regulating Act of 1773 was the first step taken by the British Government to control and regulate affairs of the East India Company. It designated the Governor of Bengal as the Governor-General of Bengal and created an Executive Council of 4 to assist him. Lord Warren Hastings was the first Governor-General of Bengal.
#
# Q.48 Absolutely Correct!
#
# Q.49 Absolutely Correct!
#
# Q.50 Incorrect!
# Right Answer is (b)
# Learn more : The first session of Indian National Congress was held from 28–31 December 1885, in Mumbai and was attended by 72 delegates. Womesh Chandra Bonnerjee was the first president of the Indian National Congress (INC), a voice of Indian opinion to the British government.
#
# Your Score: 6 / 96
